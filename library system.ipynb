# %% [markdown]
# # library system project

# %%
while True:#1 st while true
    print("*"*50)
    print("WELCOME TO PUNYANAGARI LIBRARY, STHAL - PUNE")
    print("*"*50)
    username=str(input("ENTER USERNAME"))
    if username=="snehal":
        password=input("ENTER PASSWORD-Sk123")
        if password=="Sk123":
            print("login sussfully")
            print("welcome snehal........")
            books={"mrutunjay":5,"yugandhar":5,"radheya":5}
            total_book=0
            for i in books.values():
                total_book+=i
            print("books in stocks are:",books)
            borrower_list=[]
            
            while True:#2 nd while true
                
                print("""
*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
Press 1 For Issue A Book 
Press 2 For Return A Book 
Press 3 For Available Books
Press 4 For Borrower List
Press 5 To Exit
*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
                         """)
                choice=int(input("please enter your choice"))
                name=str(input("please enter your name"))
                mobile_no=int(input("please enter 10 digit mobile no:"))
                
                if choice==1:
                    book_name=input("please enter book name(which you want to borrow) ")
                    qty=int(input("qty of book"))
                    if book_name in books and books[book_name]>= qty:
                        books[book_name]-=qty
                        total_book= total_book-qty
                        print("updated stocks:",books)
                        borrower_list.append(name)
                        print ("updated borrower list:", borrower_list)
                        print(f"{book_name} issued sucessfully to {name}")
                    else:
                        print (f"sorry, {book_name}book is currently not avilable, plz chooese another books",books)
                elif choice==2:
                    
                    book_name=input("please enter book name(which you want to return) ")
                    qty=int(input("qty of book"))
                    if book_name in books and name in borrower_list:
                        books[book_name]+=qty
                        total_book=total_book+qty
                        borrower_list.remove(name)
                        print("updated borrower list:",borrower_list)
                        print("updated stocks:",books)
                        print("return suceesfully")
                    else:
                        print("Invalid borrower name or book name. Please check and try again.")
            
                        
                elif choice ==3:
                    print("avilable books are:",books)
                    print(name, mobile_no)
                elif choice==4:
                    print("borrower names:", borrower_list)
                elif choice==5:
                    break            
                
        else:
            print("please enter valid password")
    else:
        print("please enter valid username")
